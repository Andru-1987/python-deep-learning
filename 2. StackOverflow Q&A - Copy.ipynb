#    7.01701702   7.03703704   7.05705706   7.07707708   7.0970971
#    7.11711712   7.13713714   7.15715716   7.17717718   7.1971972
#    7.21721722   7.23723724   7.25725726   7.27727728   7.2972973
#    7.31731732   7.33733734   7.35735736   7.37737738   7.3973974
#    7.41741742   7.43743744   7.45745746   7.47747748   7.4974975
#    7.51751752   7.53753754   7.55755756   7.57757758   7.5975976
#    7.61761762   7.63763764   7.65765766   7.67767768   7.6976977
#    7.71771772   7.73773774   7.75775776   7.77777778   7.7977978
#    7.81781782   7.83783784   7.85785786   7.87787788   7.8978979
#    7.91791792   7.93793794   7.95795796   7.97797798   7.997998
#    8.01801802   8.03803804   8.05805806   8.07807808   8.0980981
#    8.11811812   8.13813814   8.15815816   8.17817818   8.1981982
#    8.21821822   8.23823824   8.25825826   8.27827828   8.2982983
#    8.31831832   8.33833834   8.35835836   8.37837838   8.3983984
#    8.41841842   8.43843844   8.45845846   8.47847848   8.4984985
#    8.51851852   8.53853854   8.55855856   8.57857858   8.5985986
#    8.61861862   8.63863864   8.65865866   8.67867868   8.6986987
#    8.71871872   8.73873874   8.75875876   8.77877878   8.7987988
#    8.81881882   8.83883884   8.85885886   8.87887888   8.8988989
#    8.91891892   8.93893894   8.95895896   8.97897898   8.998999
#    9.01901902   9.03903904   9.05905906   9.07907908   9.0990991
#    9.11911912   9.13913914   9.15915916   9.17917918   9.1991992
#    9.21921922   9.23923924   9.25925926   9.27927928   9.2992993
#    9.31931932   9.33933934   9.35935936   9.37937938   9.3993994
#    9.41941942   9.43943944   9.45945946   9.47947948   9.4994995
#    9.51951952   9.53953954   9.55955956   9.57957958   9.5995996
#    9.61961962   9.63963964   9.65965966   9.67967968   9.6996997
#    9.71971972   9.73973974   9.75975976   9.77977978   9.7997998
#    9.81981982   9.83983984   9.85985986   9.87987988   9.8998999
#    9.91991992   9.93993994   9.95995996   9.97997998  10.        ]
# [-9.91991992]

# %%
Fm=1000 #%1 kHz

Fs = 2*Fm

#t = 0:1/Fs:10  #( that is, time will run from 0 to 10 with a sample at every 1/2000th second )
t=np.linspace(0,10,Fs)

Am=1   #%amplitude
m=[ Am*math.sin(2*math.pi*Fm*value) for value in t]
plt.plot(m)
plt.show()

# %%
np.random.seed(20210210)
local = np.random.randint(0, 20, size=3291)
cpm = np.random.randint(0, 10, size=2104)

distance = [6, 56, 106, 156, 207, 257, 309, 257, 206, 154, 103, 52, 
            103, 153, 204, 254, 304, 354, 303, 252, 201, 150, 99, 47, 
            98, 149, 199, 249, 300, 350, 299, 248, 196, 145, 94, 42]
dis = [str(s) for s in distance]
#print(dis)
pos = np.arange(0,len(dis))

t = linspace(0, 6, 3291) 
t1 = linspace(0, 6, 2104)

plt.figure(figsize=(12,9))
plt.plot(t, local, "g", label="LOCAL")
plt.plot(t1, cpm, "r", label="CPM")
plt.legend(loc="upper left")
plt.fill_between(t, 0, local, facecolor='green', interpolate=True)
plt.fill_between(t1, 0, cpm, facecolor='red', interpolate=False)

axes1 = plt.gca()
axes2 = axes1.twiny()
# axes2.set_xticks(distance, minor=False)
axes2.xaxis.set_major_locator(ticker.FixedLocator(pos))
axes2.xaxis.set_major_formatter(ticker.FixedFormatter(dis))
axes2.set_xlim(0,len(dis))

plt.title("Object detection")
plt.xlabel("Time in Minutes")
plt.ylabel("Number of objects")
plt.show()
# Out:
# ['6', '56', '106', '156', '207', '257', '309', '257', '206', '154', '103', '52', '103', '153', '204', '254', '304', '354', '303', '252', '201', '150', '99', '47', '98', '149', '199', '249', '300', '350', '299', '248', '196', '145', '94', '42']

# %%
n = 10
N = 1000

indice = [random.randint(0, n-1) for p in range(0, N)]
values = [random.random() for p in range(0, N)]
#print(indice)
x = zeros(n)
y = zeros(n)

def GetRandomChoice():
    index=random.choice(indice)
    value=values[index]
    return index,value

for i in range(N):
    index,value=GetRandomChoice()
    x[index]+= value

y=x.copy()    
print(x,y)
# Out:
# [ 50.2736313  106.94752567   8.53492428  17.85676292  57.20709466
#   81.65786098  49.8370366   83.86631812  56.49434847  13.01683608] [ 50.2736313  106.94752567   8.53492428  17.85676292  57.20709466
#   81.65786098  49.8370366   83.86631812  56.49434847  13.01683608]

# %%
y = np.array([-6, -5, -10, -5, -8, -3, -6, -8, -8])
X = np.array([
        [-4.95, -4.55, -10.96, -1.08, -6.52, -0.81, -7.01, -4.46, -11.54],
        [-5.87, -4.52, -11.64, -3.36, -7.45, -2.36, -7.33, -7.65, -10.03],
        [-0.76, -0.71, -0.98, 0.75, -0.86, -0.50, -0.33, -0.94, -1.03],
        [14.73, 13.74, 15.49, 24.72, 16.59, 22.44, 13.93, 11.40, 18.18],
        [4.02, 4.47, 4.18, 4.96, 4.29, 4.81, 4.32, 4.43, 4.28],
        [0.20, 0.16, 0.19, 0.16, 0.10, 0.15, 0.21, 0.16, 0.21],
        [0.45, 0.50, 0.53, 0.60, 0.48, 0.53, 0.50, 0.49, 0.55],
    ])
X=zip(*reversed(X))

#print(X)

df=pd.DataFrame({'X':X,'y':y})
columns=7
for i in range(0,columns):
    #print(i)
    df['X'+str(i)]=df.apply(lambda row: row['X'][i],axis=1)

df=df.drop('X',axis=1)
print(df)


#model_formula='y ~ X0+X1+X2+X3+X4+X5+X6'
model_formula='y ~ X0'

model_family = sm.families.Gaussian()
model_fit = glm(formula = model_formula, 
                 data = df, 
                 family = model_family).fit()

# View the results of the wells_fit model
print(model_fit.summary())

# Extract coefficients from the fitted model wells_fit
#print(model_fit.params)
intercept, slope = model_fit.params

# Print coefficients
print('Intercept =', intercept)
print('Slope =', slope)

# Extract and print confidence intervals
print(model_fit.conf_int())

df2=pd.DataFrame()
df2['X0']=np.linspace(0.50,0.70,50)

df3=pd.DataFrame()
df3['X1']=np.linspace(0.20,0.60,50)

prediction0=model_fit.predict(df2)
#prediction1=model_fit.predict(df3)

#print(prediction)

plt.plot(df2['X0'],prediction0,label='X0')
#plt.plot(df3['X1'],prediction1,label='X1')
plt.ylabel("y")
plt.xlabel("X0")
plt.show()
# Out:
#     y    X0    X1    X2     X3    X4     X5     X6
# 0  -6  0.45  0.20  4.02  14.73 -0.76  -5.87  -4.95
# 1  -5  0.50  0.16  4.47  13.74 -0.71  -4.52  -4.55
# 2 -10  0.53  0.19  4.18  15.49 -0.98 -11.64 -10.96
# 3  -5  0.60  0.16  4.96  24.72  0.75  -3.36  -1.08
# 4  -8  0.48  0.10  4.29  16.59 -0.86  -7.45  -6.52
# 5  -3  0.53  0.15  4.81  22.44 -0.50  -2.36  -0.81
# 6  -6  0.50  0.21  4.32  13.93 -0.33  -7.33  -7.01
# 7  -8  0.49  0.16  4.43  11.40 -0.94  -7.65  -4.46
# 8  -8  0.55  0.21  4.28  18.18 -1.03 -10.03 -11.54
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                    9
# Model:                            GLM   Df Residuals:                        7
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                          5.0778
# Method:                          IRLS   Log-Likelihood:                -18.951
# Date:                Thu, 11 Feb 2021   Deviance:                       35.545
# Time:                        15:20:52   Pearson chi2:                     35.5
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -9.9654      9.365     -1.064      0.287     -28.320       8.390
# X0             6.6282     18.145      0.365      0.715     -28.936      42.192
# ==============================================================================
# Intercept = -9.96541786743515
# Slope = 6.6282420749279325
#                    0          1
# Intercept -28.320349   8.389514
# X0        -28.935940  42.192424

# %%
lower_conf=np.exp(.4972-1.96*0.1017)
print(lower_conf)
upper_conf=np.exp(.4972+1.96*0.1017)
print(upper_conf)
print((1-(lower_conf/upper_conf))*100)
# Out:
# 1.346983974259511
# 2.0067811088203253
# 32.878380789057374

# %%
id_project=[1011,201,36]
time=[48,520,120]
time_df=pd.DataFrame({'id_project':id_project,'time':time})

id_project=[1011,1011,1011,201,36]
sector_l2=['Building Materials','Financial Institution','Other Materials','Building Materials','Building Materials']

material_df=pd.DataFrame({'id_project':id_project,'sector_l2':sector_l2})

merged_df=material_df.merge(time_df, on="id_project", how="left")
print(merged_df)

grouped=merged_df.groupby(['id_project','sector_l2'])['time'].sum()

grouped.plot()
plt.xticks(rotation=90)
plt.show()

print(grouped)
# Out:
#    id_project              sector_l2  time
# 0        1011     Building Materials    48
# 1        1011  Financial Institution    48
# 2        1011        Other Materials    48
# 3         201     Building Materials   520
# 4          36     Building Materials   120
# id_project  sector_l2
# 36          Building Materials       120
# 201         Building Materials       520
# 1011        Building Materials        48
#             Financial Institution     48
#             Other Materials           48
# Name: time, dtype: int64

# %%
database_dict = { 'CLO' : 'https://www.ebi.ac.uk/ols/ontologies/clo/terms?iri=http://purl.obolibrary.org/obo/',
             'EFO' : ' https://www.ebi.ac.uk/efo/',
             'ArrayExpress' : 'https://www.ebi.ac.uk/arrayexpress/experiments/',
             'ATCC' : 'https://www.atcc.org/Products/All/', # + .aspx
             'BioSample' : 'https://www.ncbi.nlm.nih.gov/biosample/?term=',
             'CCLE' : 'https://portals.broadinstitute.org/ccle/page?cell_line=',
             'Cell_Model_Passport' : 'https://cellmodelpassports.sanger.ac.uk/passports/',
             'ChEMBL-Cells' : 'https://www.ebi.ac.uk/chembldb/cell/inspect/',
             'ChEMBL-Targets' : 'https://www.ebi.ac.uk/chembldb/target/inspect/',
             'Cosmic' : 'https://cancer.sanger.ac.uk/cosmic/sample/overview?id=',
             'Cosmic-CLP' : 'https://cancer.sanger.ac.uk/cell_lines/sample/overview?id=',
             'DepMap' : 'https://depmap.org/portal/cell_line/ACH-000830',
             'GDSC' : 'https://www.cancerrxgene.org/translation/CellLine/',
             'GEO' : 'https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=',
             'IARC_TP53' : 'https://p53.iarc.fr/CellLines.aspx',
             'IGRhCellID' : 'http://igrcid.ibms.sinica.edu.tw/cgi-bin/cell_line_view.cgi?cl_name=',
             'KCLB' : 'https://cellbank.snu.ac.kr/english/sub/catalog.php?page=detail&CatNo=59&strQ=', # + &submit1=Find+it
             'LiGeA' : 'http://hpc-bioinformatics.cineca.it/fusion/cell_line/',
             'LINCS_LDP' : 'http://lincsportal.ccs.miami.edu/cells/#/view/',
             'PharmacoDB' : 'https://pharmacodb.ca/cell_lines/',
             'PRIDE' : 'https://www.ebi.ac.uk/pride/archive/projects/',
             'Wikidata' : 'https://www.wikidata.org/wiki/',
             'test' : 'test',
             'test2' : 'test2'
             }

cross_ref_dict = {'CLO': 'CLO_0007996', 'EFO': 'EFO_0002253', 'ArrayExpress': 'E-MTAB-3610', 'ATCC': 'CRL-5871', 'BioSample': 'SAMN10988000', 'CCLE': 'NCIH1436_LUNG', 'Cell_Model_Passport': 'SIDM00697', 'ChEMBL-Cells': 'CHEMBL3308893', 'ChEMBL-Targets': 'CHEMBL2366205', 'Cosmic': '2125229', 'Cosmic-CLP': '908469', 'DepMap': 'ACH-000830', 'GDSC': '908469', 'GEO': 'GSM1682805', 'IARC_TP53': '21539', 'IGRhCellID': 'NCIH1436', 'KCLB': '91436', 'LiGeA': 'CCLE_790', 'LINCS_LDP': 'LCL-1838', 'PharmacoDB': 'NCIH1436_1017_2019', 'PRIDE': 'PXD011896', 'Wikidata': 'Q54907807'}

results={}
for key,data in database_dict.items():
    print(key,data)
    if key in cross_ref_dict.keys():
        results[key]=data

print (results)

results={key:data for (key,data) in database_dict.items() if key in cross_ref_dict.keys()}
print(results)
# Out:
# CLO https://www.ebi.ac.uk/ols/ontologies/clo/terms?iri=http://purl.obolibrary.org/obo/
# EFO  https://www.ebi.ac.uk/efo/
# ArrayExpress https://www.ebi.ac.uk/arrayexpress/experiments/
# ATCC https://www.atcc.org/Products/All/
# BioSample https://www.ncbi.nlm.nih.gov/biosample/?term=
# CCLE https://portals.broadinstitute.org/ccle/page?cell_line=
# Cell_Model_Passport https://cellmodelpassports.sanger.ac.uk/passports/
# ChEMBL-Cells https://www.ebi.ac.uk/chembldb/cell/inspect/
# ChEMBL-Targets https://www.ebi.ac.uk/chembldb/target/inspect/
# Cosmic https://cancer.sanger.ac.uk/cosmic/sample/overview?id=
# Cosmic-CLP https://cancer.sanger.ac.uk/cell_lines/sample/overview?id=
# DepMap https://depmap.org/portal/cell_line/ACH-000830
# GDSC https://www.cancerrxgene.org/translation/CellLine/
# GEO https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=
# IARC_TP53 https://p53.iarc.fr/CellLines.aspx
# IGRhCellID http://igrcid.ibms.sinica.edu.tw/cgi-bin/cell_line_view.cgi?cl_name=
# KCLB https://cellbank.snu.ac.kr/english/sub/catalog.php?page=detail&CatNo=59&strQ=
# LiGeA http://hpc-bioinformatics.cineca.it/fusion/cell_line/
# LINCS_LDP http://lincsportal.ccs.miami.edu/cells/#/view/
# PharmacoDB https://pharmacodb.ca/cell_lines/
# PRIDE https://www.ebi.ac.uk/pride/archive/projects/
# Wikidata https://www.wikidata.org/wiki/
# test test
# test2 test2
# {'CLO': 'https://www.ebi.ac.uk/ols/ontologies/clo/terms?iri=http://purl.obolibrary.org/obo/', 'EFO': ' https://www.ebi.ac.uk/efo/', 'ArrayExpress': 'https://www.ebi.ac.uk/arrayexpress/experiments/', 'ATCC': 'https://www.atcc.org/Products/All/', 'BioSample': 'https://www.ncbi.nlm.nih.gov/biosample/?term=', 'CCLE': 'https://portals.broadinstitute.org/ccle/page?cell_line=', 'Cell_Model_Passport': 'https://cellmodelpassports.sanger.ac.uk/passports/', 'ChEMBL-Cells': 'https://www.ebi.ac.uk/chembldb/cell/inspect/', 'ChEMBL-Targets': 'https://www.ebi.ac.uk/chembldb/target/inspect/', 'Cosmic': 'https://cancer.sanger.ac.uk/cosmic/sample/overview?id=', 'Cosmic-CLP': 'https://cancer.sanger.ac.uk/cell_lines/sample/overview?id=', 'DepMap': 'https://depmap.org/portal/cell_line/ACH-000830', 'GDSC': 'https://www.cancerrxgene.org/translation/CellLine/', 'GEO': 'https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=', 'IARC_TP53': 'https://p53.iarc.fr/CellLines.aspx', 'IGRhCellID': 'http://igrcid.ibms.sinica.edu.tw/cgi-bin/cell_line_view.cgi?cl_name=', 'KCLB': 'https://cellbank.snu.ac.kr/english/sub/catalog.php?page=detail&CatNo=59&strQ=', 'LiGeA': 'http://hpc-bioinformatics.cineca.it/fusion/cell_line/', 'LINCS_LDP': 'http://lincsportal.ccs.miami.edu/cells/#/view/', 'PharmacoDB': 'https://pharmacodb.ca/cell_lines/', 'PRIDE': 'https://www.ebi.ac.uk/pride/archive/projects/', 'Wikidata': 'https://www.wikidata.org/wiki/'}
# {'CLO': 'https://www.ebi.ac.uk/ols/ontologies/clo/terms?iri=http://purl.obolibrary.org/obo/', 'EFO': ' https://www.ebi.ac.uk/efo/', 'ArrayExpress': 'https://www.ebi.ac.uk/arrayexpress/experiments/', 'ATCC': 'https://www.atcc.org/Products/All/', 'BioSample': 'https://www.ncbi.nlm.nih.gov/biosample/?term=', 'CCLE': 'https://portals.broadinstitute.org/ccle/page?cell_line=', 'Cell_Model_Passport': 'https://cellmodelpassports.sanger.ac.uk/passports/', 'ChEMBL-Cells': 'https://www.ebi.ac.uk/chembldb/cell/inspect/', 'ChEMBL-Targets': 'https://www.ebi.ac.uk/chembldb/target/inspect/', 'Cosmic': 'https://cancer.sanger.ac.uk/cosmic/sample/overview?id=', 'Cosmic-CLP': 'https://cancer.sanger.ac.uk/cell_lines/sample/overview?id=', 'DepMap': 'https://depmap.org/portal/cell_line/ACH-000830', 'GDSC': 'https://www.cancerrxgene.org/translation/CellLine/', 'GEO': 'https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=', 'IARC_TP53': 'https://p53.iarc.fr/CellLines.aspx', 'IGRhCellID': 'http://igrcid.ibms.sinica.edu.tw/cgi-bin/cell_line_view.cgi?cl_name=', 'KCLB': 'https://cellbank.snu.ac.kr/english/sub/catalog.php?page=detail&CatNo=59&strQ=', 'LiGeA': 'http://hpc-bioinformatics.cineca.it/fusion/cell_line/', 'LINCS_LDP': 'http://lincsportal.ccs.miami.edu/cells/#/view/', 'PharmacoDB': 'https://pharmacodb.ca/cell_lines/', 'PRIDE': 'https://www.ebi.ac.uk/pride/archive/projects/', 'Wikidata': 'https://www.wikidata.org/wiki/'}

# %%
df = pd.DataFrame({"A": [10,20,30,40,50], "B": [20, 30, 10, 40, 50], "C": [32, 234, 23, 23, 42523]})

avg_c=df['C'].mean()
print(avg_c)
sumC=df['C'].apply(lambda x: x if x<avg_c else 0).sum()
countC=df['C'].apply(lambda x: 1 if x<avg_c else None).count()
avg_c2=sumC/countC
df['C']=df['C'].apply(lambda x: avg_c2 if x >avg_c else x)
#print(avg_c2)

print(df)

model_ols = smf.ols("A ~ B+C",data=df).fit()

print(model_ols.summary())

df[['B','C']].plot()
plt.show()


df2=pd.DataFrame()
df2['B']=np.linspace(10,50,10)
df2['C']=30

df3=pd.DataFrame()
df3['B']=np.linspace(10,50,10)
df3['C']=100

predB=model_ols.predict(df2)
predC=model_ols.predict(df3)
plt.plot(df2['B'],predB,label='predict B C=30')
plt.plot(df3['B'],predC,label='predict B C=100')
plt.legend()
plt.show()

print("A change in the probability of C affects the probability of B")

intercept=model_ols.params.loc['Intercept']
B_slope=model_ols.params.loc['B']
C_slope=model_ols.params.loc['C']
#Intercept    11.874252
#B             0.760859
#C            -0.060257

print("Intercept {}\n B slope{}\n C slope{}\n".format(intercept,B_slope,C_slope))


#lower_conf,upper_conf=np.exp(model_ols.conf_int())
#print(lower_conf,upper_conf)
#print((1-(lower_conf/upper_conf))*100)

model_cov=model_ols.cov_params()
std_errorB = np.sqrt(model_cov.loc['B', 'B'])
std_errorC = np.sqrt(model_cov.loc['C', 'C'])
print('SE: ', round(std_errorB, 4),round(std_errorC, 4))

print("B z value {} C z value {}".format((B_slope/std_errorB),(C_slope/std_errorC)))
print("B feature is more statistically significant than C")
# Out:
# 8567.0
#     A   B      C
# 0  10  20   32.0
# 1  20  30  234.0
# 2  30  10   23.0
# 3  40  40   23.0
# 4  50  50   78.0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      A   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.209
# Method:                 Least Squares   F-statistic:                     1.527
# Date:                Fri, 12 Feb 2021   Prob (F-statistic):              0.396
# Time:                        11:25:03   Log-Likelihood:                -18.023
# No. Observations:                   5   AIC:                             42.05
# Df Residuals:                       2   BIC:                             40.87
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     11.8743     15.229      0.780      0.517     -53.652      77.400
# B              0.7609      0.452      1.684      0.234      -1.184       2.705
# C             -0.0603      0.079     -0.760      0.527      -0.401       0.281
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.429
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.282
# Skew:                          -0.481   Prob(JB):                        0.869
# Kurtosis:                       2.346   Cond. No.                         277.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\dnishimoto.BOISE\AppData\Local\Continuum\anaconda3\envs\deeplearning\lib\site-packages\statsmodels\stats\stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   "samples were given." % int(n), ValueWarning)
# A change in the probability of C affects the probability of B
# Intercept 11.874251554067563
#  B slope0.7608594144571961
#  C slope-0.060256845997223814
#
# SE:  0.4519 0.0793
# B z value 1.683510336937001 C z value -0.7601036314930376
# B feature is more statistically significant than C

# %%
df=pd.read_csv('ANSUR_2_M.csv', encoding = "ISO-8859-1", usecols=['Weightlbs','Heightin','Age'],dtype={'Weightlbs':np.integer,'Heightin':np.integer,'Age':np.integer})
df=df.dropna()
#mask=(df['Weightlbs']==np.nan) | (df['Heightin']==np.nan)| (df['Age']==np.nan)
#for key,item in df[mask].iterrows():
#   print(item)
df.reset_index()
df['Heightin2']=df['Heightin']**2
df['Age2']=df['Age']**2
print(df)

formula="Weightlbs ~ Heightin+Heightin2+Age+Age2"
model_ols = smf.ols(formula,data=df).fit()
minHeight=df['Heightin'].min()
maxHeight=df['Heightin'].max()
avgAge = df['Age'].median()
print(minHeight,maxHeight,avgAge)

df2=pd.DataFrame()

df2['Heightin']=np.linspace(60,100,50)
df2['Heightin2']=df2['Heightin']**2
df2['Age']=28
df2['Age2']=df['Age']**2

df3=pd.DataFrame()
df3['Heightin']=np.linspace(60,100,50)
df3['Heightin2']=df2['Heightin']**2
df3['Age']=45
df3['Age2']=df['Age']**2

prediction28=model_ols.predict(df2)
prediction45=model_ols.predict(df3)

plt.clf()
plt.plot(df2['Heightin'],prediction28,label="Age 28")
plt.plot(df3['Heightin'],prediction45,label="Age 45")
plt.ylabel="Weight lbs"
plt.xlabel="Height in"
plt.legend()
plt.show()

print('A 45 year old soldier is more probable to weight more than an 28 year old soldier')
# Out:
#       Age  Heightin  Weightlbs  Heightin2  Age2
# 0      41        71        180       5041  1681
# 1      35        68        160       4624  1225
# 2      42        68        205       4624  1764
# 3      31        66        175       4356   961
# 4      21        77        213       5929   441
# ...   ...       ...        ...        ...   ...
# 4077   22        67        160       4489   484
# 4078   22        71        194       5041   484
# 4079   23        67        186       4489   529
# 4080   22        69        165       4761   484
# 4081   38        73        218       5329  1444
#
# [4082 rows x 5 columns]
# 60 94 28.0
# A 45 year old soldier is more probable to weight more than an 28 year old soldier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

item_id =[1,2,3]
rating=[4,3,2]
gender=[0,1,1]

df=pd.DataFrame({'item_id':item_id,'rating':rating,'gender':gender})
print(df)

X=df[['rating']]
y=np.array(df['gender'])

print(X,y)

logreg=LogisticRegression(C=100)
logreg.fit(X,y)
y_predictions=logreg.predict_proba(X)[:,1]
auc=roc_auc_score(y, y_predictions)

print("Area under the curve: ", auc)

print(y_predictions)

y_pred2 = logreg.predict(X)

cm = confusion_matrix(y,y_pred2)
print(cm)
# Out:
#    item_id  rating  gender
# 0        1       4       0
# 1        2       3       1
# 2        3       2       1
#    rating
# 0       4
# 1       3
# 2       2 [0 1 1]
# Area under the curve:  1.0
# [0.05623715 0.94397376 0.99979014]
# [[1 0]
#  [0 2]]

# %%
name=['bob','jane','richard']
date=['2017-10-01','2017-10-02','2017-10-03']
score=[100,90,85]

main_df = pd.DataFrame({'name':name,'date':date,'score':score})
name=['bob','jane','richard']
date=['2017-10-01','2017-10-02','2017-10-09']
score2=[None,None,None]
goal_df = pd.DataFrame({'name':name,'date':date,'score':score2})

results=goal_df.merge(main_df, on=['name','date'],how='left')
#print(results.columns)

results=results.drop('score_x',axis=1)
results=results.rename(columns={'score_y':'score'})


filter=results['score'].isna()

def nearest(items, pivot):
    return min(items, key=lambda x: abs(pd.to_datetime(x) - pd.to_datetime(pivot)))

for key,item in results[filter].iterrows():
    print(key,item.date)
    print(main_df['date'])
    nearest_date=nearest(main_df['date'],item.date)
    filter2=main_df['date']==nearest_date
    row=main_df[filter2]
    score=int(row['score'])
    if score != np.nan:
        print(score)
        results.loc[key,'score']=score

print(results)
# Out:
# 2 2017-10-09
# 0    2017-10-01
# 1    2017-10-02
# 2    2017-10-03
# Name: date, dtype: object
# 85
#       name        date  score
# 0      bob  2017-10-01  100.0
# 1     jane  2017-10-02   90.0
# 2  richard  2017-10-09   85.0

# %%
import datetime

data={'product_id':['a','a','b','b'],
      'start':[datetime.date(2016,1,1),datetime.date(2016,1,1),datetime.date(2016,1,3),datetime.date(2016,1,1)],
      'end':[datetime.date(2016,1,4),datetime.date(2016,1,3),datetime.date(2016,1,4),datetime.date(2016,1,3)],
      'store':['X','Y','X','Y']}
df=pd.DataFrame.from_dict(data)

sales={'date':[datetime.date(2016,1,1),datetime.date(2016,1,2),datetime.date(2016,1,3),datetime.date(2016,1,4),
      datetime.date(2016,1,1),datetime.date(2016,1,2),datetime.date(2016,1,3),datetime.date(2016,1,4),
      datetime.date(2016,1,1),datetime.date(2016,1,2),datetime.date(2016,1,3),datetime.date(2016,1,4),
      datetime.date(2016,1,1),datetime.date(2016,1,2),datetime.date(2016,1,3),datetime.date(2016,1,4)],
      'product':['a','a','a','a','b','b','b','b','a','a','a','a','b','b','b','b'],
       'store':['X','X','X','X','X','X','X','X','Y','Y','Y','Y','Y','Y','Y','Y'],
       'sales':[20,30,59,110,30,40,80,20,80,59,110,30,40,80,20,10]}
df2=pd.DataFrame.from_dict(sales)

print(df)
print(df2)
# Out:
#   product_id       start         end store
# 0          a  2016-01-01  2016-01-04     X
# 1          a  2016-01-01  2016-01-03     Y
# 2          b  2016-01-03  2016-01-04     X
# 3          b  2016-01-01  2016-01-03     Y
#           date product store  sales
# 0   2016-01-01       a     X     20
# 1   2016-01-02       a     X     30
# 2   2016-01-03       a     X     59
# 3   2016-01-04       a     X    110
# 4   2016-01-01       b     X     30
# 5   2016-01-02       b     X     40
# 6   2016-01-03       b     X     80
# 7   2016-01-04       b     X     20
# 8   2016-01-01       a     Y     80
# 9   2016-01-02       a     Y     59
# 10  2016-01-03       a     Y    110
# 11  2016-01-04       a     Y     30
# 12  2016-01-01       b     Y     40
# 13  2016-01-02       b     Y     80
# 14  2016-01-03       b     Y     20
# 15  2016-01-04       b     Y     10

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

Image_file = fits.open('https://raw.githubusercontent.com/msu-cmse-courses/cmse202-S21-student/master/data/m42_40min_ir.fits')

fourty_min_ir = Image_file[0].data

plt.imshow(fourty_min_ir)
plt.show()

type(fourty_min_ir)

Image_file = fits.open('https://raw.githubusercontent.com/msu-cmse-courses/cmse202-S21-student/master/data/m42_40min_red.fits')

fourty_min_red = Image_file[0].data

plt.imshow(fourty_min_red)
plt.show()

type(fourty_min_red)

results_img=fourty_min_ir-fourty_min_red

plt.imshow(results_img)
plt.show()

# %%
np.random.seed(123)
n = 20
df = pd.DataFrame({"c_1":np.random.random(n), 
                   "c_2":np.zeros(n), 
                   "c_3":2 * np.random.random(n) - .5, 
                   "c_4":np.zeros(n)})
df.c_2 = 2 * df.c_1 - 3 * np.random.random(n)
df.c_4 = 3 * df.c_3 - 2 * np.random.random(n)        

#reformat the data for plotting...
df_plot = df[["c_1", "c_2"]].copy()
df_plot["cat"] = "set1" 
df_temp = df[["c_3", "c_4"]].copy()
df_temp.columns = ["c_1", "c_2"]
df_temp["cat"] = "set2" 
df_plot = df_plot.append(df_temp)

import scipy.stats as stats

g=sns.JointGrid(data=df_plot, x='c_1', y='c_2')
g.plot( sns.regplot,sns.scatterplot)
g=g.plot_joint(sns.kdeplot)
g=g.plot_marginals(sns.kdeplot,shade=True)
plt.show()


filter=df_plot['cat']=='set1'
plt.title('Set1')
g = (sns.jointplot(x="c_1",
             y="c_2",
             kind='scatter',
             color='green',
             data=df_plot[filter],
             marginal_kws=dict(bins=10, rug=True))
    .plot_joint(sns.regplot)
    .plot_joint(sns.kdeplot))
plt.show()

filter=df_plot['cat']=='set2'
plt.title('Set2')
g = (sns.jointplot(x="c_1",
             y="c_2",
             kind='scatter',
             color='blue',
             data=df_plot[filter],
             marginal_kws=dict(bins=10, rug=True))
    .plot_joint(sns.regplot)
    .plot_joint(sns.kdeplot))

plt.show()
#printg=g.annotate(stats.pearsonr)
# Out:
# C:\Users\dnishimoto.BOISE\AppData\Local\Continuum\anaconda3\envs\deeplearning\lib\site-packages\seaborn\axisgrid.py:2036: UserWarning: The marginal plotting function has changed to `histplot`, which does not accept the following argument(s): rug.
#   warnings.warn(msg, UserWarning)
# C:\Users\dnishimoto.BOISE\AppData\Local\Continuum\anaconda3\envs\deeplearning\lib\site-packages\seaborn\axisgrid.py:2036: UserWarning: The marginal plotting function has changed to `histplot`, which does not accept the following argument(s): rug.
#   warnings.warn(msg, UserWarning)

# %%
Month =["01/01/2020","01/02/2020","01/03/2020"]
Name=["FileName1 - Example","FileName2 - Example","FileName3 - Example"]
ID=[1,2,3]
df=pd.DataFrame({'Month':Month,'Name':Name,'ID':ID})
df=df.set_index('ID')
print(df.index)
# Out:
# Int64Index([1, 2, 3], dtype='int64', name='ID')

# %%
dataDict={'date': {0: '10/3/2018', 1: '10/3/2018', 2: '10/3/2018', 3: '10/3/2018', 4: '10/3/2018', 5: '10/3/2018', 6: '10/3/2018', 7: '10/3/2018', 8: '10/3/2018', 9: '10/3/2018', 10: '10/3/2018', 11: '10/3/2018', 12: '10/3/2018', 13: '10/3/2018', 14: '10/3/2018', 15: '10/3/2018', 16: '10/3/2018', 17: '10/3/2018', 18: '10/3/2018', 19: '10/3/2018', 20: '10/4/2018', 21: '10/4/2018', 22: '10/4/2018', 23: '10/4/2018', 24: '10/4/2018'}, 'time': {0: '6:15:00', 1: '6:45:00', 2: '7:45:00', 3: '9:00:00', 4: '9:25:00', 5: '9:30:00', 6: '11:00:00', 7: '11:30:00', 8: '13:30:00', 9: '13:50:00', 10: '15:00:00', 11: '15:25:00', 12: '16:25:00', 13: '18:00:00', 14: '19:00:00', 15: '19:30:00', 16: '20:00:00', 17: '22:05:00', 18: '22:15:00', 19: '23:40:00', 20: '6:58:00', 21: '13:00:00', 22: '16:00:00', 23: '17:00:00', 24: '18:00:00'}, 'X': {0: 3, 1: 3, 2: 3, 3: 4, 4: 3, 5: 3, 6: 4, 7: 3, 8: 3, 9: 3, 10: 4, 11: 3, 12: 3, 13: 3, 14: 3, 15: 3, 16: 4, 17: 3, 18: 3, 19: 3, 20: 3, 21: 3, 22: 4, 23: 3, 24: 3}}
#df=pd.read_csv("time_temp.csv",sep="\s+")
#print(df.to_dict())
df=pd.DataFrame(dataDict)
df['X']=df['X'].astype(int)
#print(df)
myList=[3]
df=df.assign(find_4=lambda x: x[x['X']==4]['time']).fillna('')
#df['find_4']=df.apply(lambda x: x['time'] if  '3' in x['X'] else None,axis=1)
print(df)
# Out:
#          date      time  X    find_4
# 0   10/3/2018   6:15:00  3
# 1   10/3/2018   6:45:00  3
# 2   10/3/2018   7:45:00  3
# 3   10/3/2018   9:00:00  4   9:00:00
# 4   10/3/2018   9:25:00  3
# 5   10/3/2018   9:30:00  3
# 6   10/3/2018  11:00:00  4  11:00:00
# 7   10/3/2018  11:30:00  3
# 8   10/3/2018  13:30:00  3
# 9   10/3/2018  13:50:00  3
# 10  10/3/2018  15:00:00  4  15:00:00
# 11  10/3/2018  15:25:00  3
# 12  10/3/2018  16:25:00  3
# 13  10/3/2018  18:00:00  3
# 14  10/3/2018  19:00:00  3
# 15  10/3/2018  19:30:00  3
# 16  10/3/2018  20:00:00  4  20:00:00
# 17  10/3/2018  22:05:00  3
# 18  10/3/2018  22:15:00  3
# 19  10/3/2018  23:40:00  3
# 20  10/4/2018   6:58:00  3
# 21  10/4/2018  13:00:00  3
# 22  10/4/2018  16:00:00  4  16:00:00
# 23  10/4/2018  17:00:00  3
# 24  10/4/2018  18:00:00  3

# %%
df = pd.DataFrame({'id': [1, 2, 3],
 'custom': [[],
  [{'key': 'impact', 'name': 'Impact', 'value': 'abc', 'type': 'string'},
   {'key': 'proposed_status',
    'name': 'PROPOSED Status [temporary]',
    'value': 'pqr',
    'type': 'string'}],
  [{'key': 'impact', 'name': 'Impact', 'value': 'xyz', 'type': 'string'}]]})

# expand out lists, reset_index() so join() will work
df2 = df.explode("custom").reset_index(drop=True)
# join to keep "id"
df2 = (df2.join(df2["custom"]
    # expand embedded dict
    .apply(pd.Series))
    .loc[:,["id","key","value"]]
 # empty list generate spurios NaN, remove
     .dropna()
 # turn key attribute into column
 .set_index(["id","key"]).unstack(1)
 # cleanup multi index columns
 .droplevel(0, axis=1)
)

df.merge(df2, on="id", how="left")
# Out:
#    id                                             custom impact  \
# 0   1                                                 []    NaN
# 1   2  [{'key': 'impact', 'name': 'Impact', 'value': ...    abc
# 2   3  [{'key': 'impact', 'name': 'Impact', 'value': ...    xyz
#
#   proposed_status
# 0             NaN
# 1             pqr
# 2             NaN

# %%
dfaa = pd.DataFrame([['id1', 1, 2, 3, 3], ['id2',4, 5, 6,6 ], ['id3', 7, 8, 9,9]], columns=['prod_id','a', 'b','c','number of prod variants'])
dfbb = pd.DataFrame([['id1', 1.1, 2.2, 3.3, 3], ['id2',4.4, 5.4, 6.6,6 ], ['id3', 7.7, 8.8, 9.9,9]], columns=['prod_id','a', 'b','c','number of prod variants'])

def prepdf(df, cat):
    return (df.loc[:,[c for c in dfaa.columns if "number" not in c]]
     .set_index("prod_id")
     .stack()
     .to_frame()
     .assign(cat=cat)
    )

dfm = (pd.concat([
    prepdf(dfaa, "VALS"),
    prepdf(dfbb, "V_UN")])
 .set_index("cat", append=True)
 .unstack([2,1])
 .droplevel(0, axis=1)
 .join(dfbb.loc[:,["prod_id","number of prod variants"]]
       .set_index("prod_id")
      .rename(columns={"number of prod variants":("","number of prod variants")}))
)
print(dfm)
# Out:
# cat     VALS           V_UN
#            a    b    c    a    b    c number of prod variants
# prod_id
# id1      1.0  2.0  3.0  1.1  2.2  3.3                       3
# id2      4.0  5.0  6.0  4.4  5.4  6.6                       6
# id3      7.0  8.0  9.0  7.7  8.8  9.9                       9
# C:\Users\dnishimoto.BOISE\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\merge.py:643: UserWarning: merging between different levels can give an unintended result (2 levels on the left,1 on the right)
#   warnings.warn(msg, UserWarning)

# %%
my_list = [['Chicago', 'A', 112, 8],
      ['Philly', 'A', 252, 19],
      ['LA', 'A', 411, 12], 
      ['Chicago', 'B', 112, 8],
      ['Philly', 'B', 252, 19],
      ['LA', 'B', 411, 12]]
df1 = pd.DataFrame(columns=['City', 'Firm', 'Employee', 'Revenue'], 
                    data=my_list)
df1 = df1.set_index(['City', 'Firm'])#.unstack()


print(df1.index)
print("slice")
df1.loc[('LA','B'),'Revenue']=14
df1.loc[('LA','A'),'Revenue']=13

df1 = df1.unstack()
print(df1)
# Out:
# MultiIndex([('Chicago', 'A'),
#             ( 'Philly', 'A'),
#             (     'LA', 'A'),
#             ('Chicago', 'B'),
#             ( 'Philly', 'B'),
#             (     'LA', 'B')],
#            names=['City', 'Firm'])
# slice
#         Employee      Revenue
# Firm           A    B       A   B
# City
# Chicago      112  112       8   8
# LA           411  411      13  14
# Philly       252  252      19  19

# %%
from pandas.tseries.offsets import MonthEnd
#https://stackoverflow.com/questions/66188566/change-multiindex-level-valueerror-on-level-0-code-max-length-of-level/66188740#66188740

def get_example_df(notbefore=None):
    np.random.seed(0)
    n = 3
    dates = pd.date_range('2000', freq='MS', periods=n)
    names = list('ab')
    df = pd.DataFrame(
        np.random.randint(10, size=n * len(names)),
        columns=['x'],
        index=pd.MultiIndex.from_product([dates, names],
                                         names=('date', 'name'))
    )
    if notbefore:
        dates = df.index.get_level_values('date')
        df = df.loc[dates >= notbefore]
    return df

def merge(list1, list2): 
      
    merged_list = [(list1[i], list2[i]) for i in range(0, len(list1))] 
    return merged_list 
      

df=get_example_df()
endOfMonth=[pd.to_datetime(x[0].strftime("%Y-%m"))+MonthEnd(1) for x in df.index]
df.reset_index(inplace=True) 
df['date']=endOfMonth
df=df.set_index(['date','name'])
#df.index=new_index
#df=df.set_index(new_index)
#df['date2']=df.index['date']+MonthEnd[0]
print(df)
# Out:
# MultiIndex([('2000-01-01', 'a'),
#             ('2000-01-01', 'b'),
#             ('2000-02-01', 'a'),
#             ('2000-02-01', 'b'),
#             ('2000-03-01', 'a'),
#             ('2000-03-01', 'b')],
#            names=['date', 'name'])
#                  x
# date       name
# 2000-01-31 a     5
#            b     0
# 2000-02-29 a     3
#            b     3
# 2000-03-31 a     7
#            b     9
